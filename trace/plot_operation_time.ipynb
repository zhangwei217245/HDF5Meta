# %%
# %matplotlib notebook

import numpy as np
import matplotlib.pyplot as plt

ins_1m_no_idx = np.loadtxt('insert_1M_time_no_index.txt', delimiter = ',', dtype=float);

xlabels = ['1M_No_Index']

fig, ax = plt.subplots(1,1)

ax.plot(data)
# ax.boxplot(ins_1m_no_idx, showmeans=True, showfliers=False)
ax.set(xlabel='Request ID', ylabel='Time(ms)', 
#        xticklabels=[],
       title='Duration of 1M Insertion Operations')
ax.grid()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x13232af60>],
#  'caps': [<matplotlib.lines.Line2D at 0x1350e7c50>,
#   <matplotlib.lines.Line2D at 0x132322b70>],
#  'fliers': [],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x132322da0>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x1322e4518>,
#   <matplotlib.lines.Line2D at 0x1350e7a90>]}
